# %%
"""
This is an upgraded version of Ceshine's LGBM starter script.
"""
# Out:
# "\nThis is an upgraded version of Ceshine's LGBM starter script.\n"

# %%
from datetime import date, timedelta
import calendar as ca
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
import lightgbm as lgb

# %%
print('Loading Data')
df_train = pd.read_csv('train.csv',dtype={'onpromotion': bool},
    converters={'unit_sales': lambda u: np.log1p(float(u)) if float(u) > 0 else 0},
    parse_dates=["date"], skiprows=range(1, 101688780) )
# read data starting from 2017-1-1
# Out:
# Loading Data

# %%
item_nbr_u = df_train.item_nbr.unique()

# %%
df_test = pd.read_csv("test.csv", dtype={'onpromotion': bool}, parse_dates=["date"]).set_index(['store_nbr', 'item_nbr', 'date'])

# %%
date_index = pd.date_range(df_train['date'].min(), df_train['date'].max())

# %%
items = pd.read_csv("items.csv").set_index("item_nbr")

# %%
promo_2017_train = df_train.set_index(["store_nbr", "item_nbr", "date"])[["onpromotion"]].unstack().fillna(False)
promo_2017_train.columns = promo_2017_train.columns.get_level_values(1)

# %%
promo_2017_test = df_test[["onpromotion"]].unstack().fillna(False)
promo_2017_test.columns = promo_2017_test.columns.get_level_values(1)

# %%
promo_2017_test = promo_2017_test.reindex(promo_2017_train.index).fillna(False)

# %%
promo_2017 = pd.concat([promo_2017_train, promo_2017_test], axis=1)
del promo_2017_test, promo_2017_train

# %%
df_2017 = df_train.set_index(["store_nbr", "item_nbr", "date"])[["unit_sales"]].unstack().fillna(0)
df_2017.columns = df_2017.columns.get_level_values(1)

# %%
items = items.reindex(df_2017.index.get_level_values(1))

# %%
items
# Out:
#                   family  class  perishable
# item_nbr
# 96995          GROCERY I   1093           0
# 99197          GROCERY I   1067           0
# 103520         GROCERY I   1028           0
# 103665      BREAD/BAKERY   2712           1
# 105574         GROCERY I   1045           0
# 105575         GROCERY I   1045           0
# 105577         GROCERY I   1045           0
# 105693         GROCERY I   1034           0
# 105737         GROCERY I   1044           0
# 105857         GROCERY I   1092           0
# 106716         GROCERY I   1032           0
# 108079         GROCERY I   1030           0
# 108634         GROCERY I   1075           0
# 108696              DELI   2636           1
# 108698              DELI   2644           1
# 108701              DELI   2644           1
# 108786          CLEANING   3044           0
# 108797         GROCERY I   1004           0
# 108831           POULTRY   2416           1
# 108862         GROCERY I   1062           0
# 108952          CLEANING   3024           0
# 111223         GROCERY I   1034           0
# 111397         GROCERY I   1072           0
# 112830         GROCERY I   1044           0
# 114778         GROCERY I   1016           0
# 114790         GROCERY I   1004           0
# 114799     PERSONAL CARE   4126           0
# 114800     PERSONAL CARE   4126           0
# 115267          CLEANING   3034           0
# 115611         GROCERY I   1014           0
# ...                  ...    ...         ...
# 2081056   PREPARED FOODS   2986           1
# 2081064   PREPARED FOODS   2966           1
# 2081095   PREPARED FOODS   2962           1
# 2081142   PREPARED FOODS   2980           1
# 2081161   PREPARED FOODS   2966           1
# 2083837        BEVERAGES   1118           0
# 2083859        BEVERAGES   1118           0
# 2084278        BEVERAGES   1122           0
# 2084557         CLEANING   3040           0
# 2086882            DAIRY   2166           1
# 2087374            DAIRY   2162           1
# 2087409        BEVERAGES   1132           0
# 2087543            DAIRY   2162           1
# 2087567            DAIRY   2162           1
# 2087933        BEVERAGES   1114           0
# 2087978        BEVERAGES   1114           0
# 2088922        GROCERY I   1076           0
# 2089036        GROCERY I   1034           0
# 2089339        GROCERY I   1006           0
# 2099230           BEAUTY   4252           0
# 2101795           BEAUTY   4222           0
# 2103250           BEAUTY   4254           0
# 2105347           BEAUTY   4254           0
# 2106464        BEVERAGES   1148           0
# 2108569        GROCERY I   1086           0
# 2109909        GROCERY I   1074           0
# 2110456        BEVERAGES   1120           0
# 2113343        BEVERAGES   1114           0
# 2113914         CLEANING   3040           0
# 2116416        GROCERY I   1060           0
#
# [167515 rows x 3 columns]

# %%
def get_timespan(df, dt, minus, periods, freq='D'):
    return df[pd.date_range(dt - timedelta(days=minus), periods=periods, freq=freq)]

# %%
def prepare_dataset(t2017, is_train=True):
    X = pd.DataFrame({
        "promo_14_2017": get_timespan(promo_2017, t2017, 14, 14).sum(axis=1).values,
        "promo_60_2017": get_timespan(promo_2017, t2017, 60, 60).sum(axis=1).values,
        "promo_140_2017": get_timespan(promo_2017, t2017, 140, 140).sum(axis=1).values
    })

    for i in range(16):
        X["promo_{}".format(i)] = promo_2017[t2017 + timedelta(days=i)].values.astype(np.uint8)
        
    for i in range(7):
        X['mean_4_dow{}_2017'.format(i)] = get_timespan(df_2017, t2017, 28-i, 4, freq='7D').mean(axis=1).values
        X['mean_20_dow{}_2017'.format(i)] = get_timespan(df_2017, t2017, 140-i, 20, freq='7D').mean(axis=1).values 
        
    for i in range(1,15,1):
        X['day_{}_2017'.format(i)] = get_timespan(df_2017, t2017, i, 1).values.ravel()
        
    for i in range(2,15,1):
        X['mean_{}_2017'.format(i)] = get_timespan(df_2017, t2017, i, i).mean(axis=1).values
        
    X['mean_30_2017'.format(i)] = get_timespan(df_2017, t2017, 30, 30).mean(axis=1).values
    X['mean_60_2017'.format(i)] = get_timespan(df_2017, t2017, 60, 60).mean(axis=1).values
    X['mean_140_2017'.format(i)] = get_timespan(df_2017, t2017, 60, 60).mean(axis=1).values

    if is_train:
        y = df_2017[pd.date_range(t2017, periods=16)].values
        return X, y
        
    return X

# %%
t2017 = date(2017, 7, 5)
X_l, y_l = [], []
for i in range(4):
    delta = timedelta(days=7 * i)
    X_tmp, y_tmp = prepare_dataset(
        t2017 + delta
    )
    X_l.append(X_tmp)
    y_l.append(y_tmp)
X_train = pd.concat(X_l, axis=0)
y_train = np.concatenate(y_l, axis=0)
del X_l, y_l
X_val, y_val = prepare_dataset(date(2017, 7, 26))
X_test = prepare_dataset(date(2017, 8, 16), is_train=False)

# %%
params = {
    'num_leaves': 31,
    'objective': 'regression',
    'min_data_in_leaf': 200,
    'learning_rate': 0.07,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.85,
    'bagging_freq': 3,
    'metric': 'l2_root',
    'num_threads': 4
}

MAX_ROUNDS = 500
val_pred = []
test_pred = []
cate_vars = []

# %%
for i in range(16):
    print("=" * 50)
    print("Step %d" % (i+1))
    print("=" * 50)
    dtrain = lgb.Dataset(
        X_train, label=y_train[:, i],
        categorical_feature=cate_vars,
        weight=pd.concat([items["perishable"]] * 4) * 0.25 + 1
    )
    dval = lgb.Dataset(
        X_val, label=y_val[:, i], reference=dtrain,
        weight=items["perishable"] * 0.25 + 1,
        categorical_feature=cate_vars)
    bst = lgb.train(
        params, dtrain, num_boost_round=MAX_ROUNDS,
        valid_sets=[dtrain, dval], early_stopping_rounds=50, verbose_eval=100
    )
    print("\n".join(("%s: %.2f" % x) for x in sorted(
        zip(X_train.columns, bst.feature_importance("gain")),
        key=lambda x: x[1], reverse=True
    )))
    val_pred.append(bst.predict(
        X_val, num_iteration=bst.best_iteration or MAX_ROUNDS))
    test_pred.append(bst.predict(
        X_test, num_iteration=bst.best_iteration or MAX_ROUNDS))
# Out:
# ==================================================
# Step 1
# ==================================================
# /Users/hetty/anaconda/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.542099	valid_1's rmse: 0.538469
# [200]	training's rmse: 0.53768	valid_1's rmse: 0.533979
# [300]	training's rmse: 0.53487	valid_1's rmse: 0.53114
# [400]	training's rmse: 0.532429	valid_1's rmse: 0.528701
# [500]	training's rmse: 0.530294	valid_1's rmse: 0.526548
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.530294	valid_1's rmse: 0.526548
# mean_7_2017: 1277555.85
# mean_14_2017: 944640.51
# mean_9_2017: 609652.96
# mean_8_2017: 174058.60
# promo_0: 101190.66
# mean_30_2017: 74737.98
# mean_5_2017: 66786.85
# mean_20_dow0_2017: 63927.49
# mean_2_2017: 59243.93
# mean_4_dow0_2017: 56033.90
# day_1_2017: 51050.91
# promo_14_2017: 32334.22
# mean_60_2017: 27522.52
# mean_12_2017: 18380.96
# mean_3_2017: 12211.07
# promo_7: 10649.19
# day_14_2017: 7190.57
# mean_4_dow2_2017: 7090.15
# mean_11_2017: 7051.04
# mean_140_2017: 6877.38
# promo_60_2017: 6501.07
# mean_20_dow2_2017: 5942.75
# day_7_2017: 5641.03
# mean_4_2017: 4852.02
# promo_140_2017: 4702.50
# promo_14: 3954.81
# mean_6_2017: 3825.93
# mean_20_dow4_2017: 3797.17
# day_12_2017: 3731.13
# day_2_2017: 3097.13
# mean_20_dow6_2017: 2865.39
# day_3_2017: 2682.97
# day_5_2017: 2682.42
# day_4_2017: 2546.58
# promo_15: 2465.17
# day_6_2017: 2401.93
# mean_4_dow6_2017: 2141.39
# day_10_2017: 1973.71
# mean_20_dow3_2017: 1924.37
# mean_4_dow5_2017: 1847.90
# day_13_2017: 1780.79
# day_9_2017: 1764.83
# mean_20_dow1_2017: 1696.65
# day_8_2017: 1689.05
# mean_20_dow5_2017: 1607.14
# mean_13_2017: 1603.98
# mean_4_dow4_2017: 1491.16
# mean_10_2017: 1477.48
# day_11_2017: 1437.79
# mean_4_dow1_2017: 1371.04
# mean_4_dow3_2017: 1308.62
# promo_2: 1216.42
# promo_13: 1209.62
# promo_11: 1145.64
# promo_9: 890.51
# promo_3: 697.89
# promo_5: 674.31
# promo_1: 591.68
# promo_4: 524.64
# promo_6: 458.61
# promo_12: 409.31
# promo_10: 246.82
# promo_8: 156.51
# ==================================================
# Step 2
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.563793	valid_1's rmse: 0.564874
# [200]	training's rmse: 0.559588	valid_1's rmse: 0.560145
# [300]	training's rmse: 0.556786	valid_1's rmse: 0.557228
# [400]	training's rmse: 0.554487	valid_1's rmse: 0.554826
# [500]	training's rmse: 0.552249	valid_1's rmse: 0.55255
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.552249	valid_1's rmse: 0.55255
# mean_14_2017: 916564.64
# mean_7_2017: 694592.66
# mean_8_2017: 391310.12
# mean_13_2017: 279616.35
# mean_6_2017: 200731.14
# mean_30_2017: 168210.76
# mean_9_2017: 77452.35
# promo_1: 76925.54
# mean_20_dow1_2017: 54840.30
# mean_60_2017: 35877.38
# promo_14_2017: 26931.98
# mean_5_2017: 22185.42
# mean_4_dow1_2017: 20095.66
# day_1_2017: 19329.95
# mean_2_2017: 18546.76
# mean_140_2017: 8201.25
# mean_20_dow2_2017: 7364.77
# promo_3: 7124.19
# promo_0: 6301.54
# mean_3_2017: 6224.56
# promo_60_2017: 5904.28
# mean_4_dow2_2017: 5880.98
# day_13_2017: 5445.32
# mean_12_2017: 4874.35
# mean_10_2017: 4864.61
# mean_4_2017: 4755.38
# mean_20_dow4_2017: 4323.95
# promo_5: 4166.74
# day_6_2017: 3964.19
# promo_140_2017: 3636.89
# day_4_2017: 3222.42
# mean_20_dow0_2017: 3094.00
# day_14_2017: 2966.29
# day_12_2017: 2945.10
# mean_20_dow6_2017: 2823.63
# day_3_2017: 2817.22
# day_10_2017: 2764.38
# day_5_2017: 2428.38
# promo_4: 2246.23
# day_2_2017: 2233.12
# mean_11_2017: 2111.49
# mean_4_dow4_2017: 2078.74
# promo_2: 1900.25
# day_7_2017: 1886.24
# mean_4_dow0_2017: 1885.23
# day_9_2017: 1879.98
# mean_4_dow6_2017: 1853.20
# mean_20_dow5_2017: 1830.71
# promo_7: 1695.26
# mean_20_dow3_2017: 1652.24
# day_11_2017: 1536.17
# day_8_2017: 1529.07
# mean_4_dow3_2017: 1489.56
# mean_4_dow5_2017: 1433.11
# promo_6: 735.52
# promo_8: 636.53
# promo_14: 569.26
# promo_9: 415.01
# promo_13: 356.37
# promo_15: 351.72
# promo_11: 195.01
# promo_10: 120.52
# promo_12: 65.62
# ==================================================
# Step 3
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.568722	valid_1's rmse: 0.577692
# [200]	training's rmse: 0.563876	valid_1's rmse: 0.572601
# [300]	training's rmse: 0.560708	valid_1's rmse: 0.569329
# [400]	training's rmse: 0.557975	valid_1's rmse: 0.566457
# [500]	training's rmse: 0.555493	valid_1's rmse: 0.563933
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.555493	valid_1's rmse: 0.563933
# mean_7_2017: 1033453.25
# mean_14_2017: 983223.13
# mean_13_2017: 329416.21
# mean_4_dow2_2017: 259439.86
# mean_12_2017: 224306.55
# mean_30_2017: 176591.41
# mean_20_dow2_2017: 161254.23
# mean_6_2017: 106840.88
# promo_2: 101230.82
# mean_5_2017: 30096.00
# promo_14_2017: 27197.38
# mean_60_2017: 10538.28
# mean_2_2017: 9760.12
# day_1_2017: 8235.83
# promo_140_2017: 8105.96
# promo_60_2017: 7866.06
# day_5_2017: 7391.03
# mean_20_dow4_2017: 6530.24
# promo_0: 6088.34
# promo_3: 5391.76
# day_12_2017: 5335.61
# mean_140_2017: 5248.55
# day_4_2017: 5180.30
# mean_9_2017: 4979.40
# mean_8_2017: 4882.21
# promo_9: 4764.99
# mean_4_2017: 4432.53
# mean_20_dow5_2017: 3981.67
# mean_3_2017: 3856.81
# mean_4_dow1_2017: 3845.23
# mean_20_dow1_2017: 3569.13
# promo_5: 3183.04
# mean_20_dow0_2017: 3067.75
# promo_7: 3034.34
# mean_4_dow0_2017: 2760.63
# mean_20_dow6_2017: 2708.91
# day_10_2017: 2662.07
# day_13_2017: 2532.33
# day_6_2017: 2497.52
# mean_4_dow3_2017: 2404.54
# promo_4: 2301.74
# mean_20_dow3_2017: 2288.77
# day_3_2017: 2178.68
# promo_1: 2145.17
# day_2_2017: 2068.27
# day_9_2017: 2053.45
# mean_4_dow6_2017: 2016.94
# day_14_2017: 1888.49
# day_11_2017: 1858.40
# day_7_2017: 1783.00
# mean_4_dow4_2017: 1727.42
# promo_14: 1718.89
# mean_4_dow5_2017: 1654.65
# promo_10: 1506.89
# day_8_2017: 1384.17
# promo_11: 1352.62
# mean_11_2017: 1204.39
# mean_10_2017: 1044.04
# promo_13: 1026.90
# promo_6: 901.57
# promo_8: 811.88
# promo_15: 608.67
# promo_12: 151.17
# ==================================================
# Step 4
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.581372	valid_1's rmse: 0.589575
# [200]	training's rmse: 0.576614	valid_1's rmse: 0.584434
# [300]	training's rmse: 0.573471	valid_1's rmse: 0.581109
# [400]	training's rmse: 0.570786	valid_1's rmse: 0.578292
# [500]	training's rmse: 0.568466	valid_1's rmse: 0.575905
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.568466	valid_1's rmse: 0.575905
# mean_12_2017: 1240084.87
# mean_13_2017: 661934.31
# mean_5_2017: 441453.04
# mean_7_2017: 334093.05
# mean_11_2017: 312791.70
# mean_4_dow3_2017: 218713.44
# mean_6_2017: 179615.10
# mean_30_2017: 170691.93
# mean_20_dow3_2017: 105342.24
# promo_3: 78072.32
# mean_14_2017: 38920.08
# mean_60_2017: 37349.60
# promo_14_2017: 25099.13
# mean_140_2017: 18745.50
# mean_4_2017: 14604.30
# day_4_2017: 7442.12
# day_3_2017: 6681.72
# mean_4_dow4_2017: 6447.51
# promo_0: 5541.58
# promo_5: 5463.21
# day_1_2017: 5386.79
# mean_3_2017: 5296.80
# mean_20_dow2_2017: 5115.10
# promo_60_2017: 4965.78
# promo_140_2017: 4948.50
# mean_20_dow5_2017: 4924.36
# mean_4_dow2_2017: 4534.41
# promo_7: 3915.45
# mean_20_dow6_2017: 3511.34
# mean_20_dow0_2017: 3439.65
# mean_2_2017: 3402.94
# promo_4: 3164.71
# promo_2: 3134.96
# day_10_2017: 3024.48
# day_11_2017: 2609.48
# day_12_2017: 2491.78
# promo_1: 2476.80
# mean_20_dow4_2017: 2472.77
# day_5_2017: 2466.21
# mean_20_dow1_2017: 2305.90
# day_6_2017: 2172.22
# day_9_2017: 2156.54
# mean_4_dow6_2017: 1875.21
# mean_4_dow1_2017: 1849.50
# day_2_2017: 1820.88
# day_8_2017: 1785.47
# mean_4_dow5_2017: 1684.20
# day_14_2017: 1632.93
# mean_8_2017: 1631.43
# mean_4_dow0_2017: 1595.05
# day_7_2017: 1444.52
# promo_6: 1381.13
# day_13_2017: 1301.76
# promo_14: 1083.48
# mean_10_2017: 1024.48
# mean_9_2017: 919.27
# promo_9: 698.76
# promo_8: 583.22
# promo_10: 570.33
# promo_15: 477.32
# promo_13: 371.81
# promo_11: 181.23
# promo_12: 122.74
# ==================================================
# Step 5
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.588582	valid_1's rmse: 0.5925
# [200]	training's rmse: 0.583468	valid_1's rmse: 0.587038
# [300]	training's rmse: 0.580173	valid_1's rmse: 0.583593
# [400]	training's rmse: 0.577421	valid_1's rmse: 0.580797
# [500]	training's rmse: 0.57492	valid_1's rmse: 0.578298
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.57492	valid_1's rmse: 0.578298
# mean_11_2017: 2373242.59
# mean_4_dow4_2017: 491137.37
# mean_4_2017: 451329.83
# mean_10_2017: 200072.17
# mean_20_dow4_2017: 172433.95
# mean_5_2017: 151061.71
# mean_12_2017: 90896.26
# promo_4: 78590.97
# mean_30_2017: 59769.75
# mean_14_2017: 27620.93
# day_3_2017: 25487.19
# promo_14_2017: 24750.19
# mean_60_2017: 19605.64
# mean_3_2017: 16571.22
# mean_140_2017: 13937.06
# day_10_2017: 9370.38
# mean_4_dow3_2017: 7925.13
# promo_5: 7127.99
# promo_7: 6522.08
# promo_60_2017: 5773.08
# mean_6_2017: 5576.26
# promo_140_2017: 5360.25
# promo_3: 4764.67
# mean_20_dow0_2017: 4598.12
# promo_0: 4443.72
# mean_20_dow1_2017: 3835.87
# mean_2_2017: 3651.72
# mean_20_dow6_2017: 3517.25
# promo_2: 3276.04
# mean_20_dow3_2017: 3209.40
# day_1_2017: 3094.33
# mean_20_dow2_2017: 2990.28
# promo_6: 2989.67
# mean_20_dow5_2017: 2824.59
# day_4_2017: 2566.51
# promo_1: 2468.33
# day_2_2017: 2442.43
# day_11_2017: 2345.11
# mean_4_dow0_2017: 2227.60
# mean_4_dow5_2017: 2073.32
# mean_4_dow6_2017: 2040.01
# mean_7_2017: 1974.69
# day_5_2017: 1932.69
# mean_4_dow2_2017: 1911.38
# mean_4_dow1_2017: 1874.28
# day_9_2017: 1835.21
# day_12_2017: 1827.80
# day_14_2017: 1705.63
# day_6_2017: 1698.82
# promo_11: 1690.34
# mean_13_2017: 1660.26
# promo_14: 1635.73
# day_13_2017: 1555.97
# day_8_2017: 1508.29
# day_7_2017: 1268.92
# mean_8_2017: 1245.64
# mean_9_2017: 1150.43
# promo_9: 919.78
# promo_8: 867.11
# promo_13: 607.22
# promo_15: 592.32
# promo_10: 568.21
# promo_12: 398.40
# ==================================================
# Step 6
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.590264	valid_1's rmse: 0.594961
# [200]	training's rmse: 0.586086	valid_1's rmse: 0.590387
# [300]	training's rmse: 0.583041	valid_1's rmse: 0.587266
# [400]	training's rmse: 0.58038	valid_1's rmse: 0.584604
# [500]	training's rmse: 0.577904	valid_1's rmse: 0.582154
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.577904	valid_1's rmse: 0.582154
# mean_10_2017: 1180804.63
# mean_9_2017: 562631.97
# mean_11_2017: 557299.43
# mean_14_2017: 324008.82
# mean_30_2017: 263752.53
# mean_3_2017: 156351.11
# promo_5: 79393.85
# mean_4_dow5_2017: 73380.68
# mean_60_2017: 60880.64
# mean_20_dow5_2017: 59637.38
# mean_4_2017: 40802.84
# mean_7_2017: 31287.64
# promo_14_2017: 23314.22
# mean_140_2017: 18968.77
# mean_2_2017: 13533.98
# promo_3: 8176.93
# promo_6: 6405.17
# promo_7: 6067.47
# mean_20_dow6_2017: 6061.55
# mean_4_dow6_2017: 5782.87
# mean_6_2017: 5207.91
# promo_60_2017: 5169.40
# mean_20_dow0_2017: 4815.76
# mean_13_2017: 4179.61
# day_1_2017: 4037.23
# mean_5_2017: 3985.36
# day_9_2017: 3781.13
# promo_0: 3771.56
# promo_140_2017: 3413.97
# day_2_2017: 3278.51
# day_6_2017: 3260.85
# day_3_2017: 2997.08
# mean_20_dow2_2017: 2996.94
# promo_1: 2900.04
# mean_4_dow0_2017: 2836.01
# mean_20_dow3_2017: 2759.27
# day_10_2017: 2683.51
# mean_4_dow4_2017: 2612.86
# promo_4: 2469.51
# day_7_2017: 2396.64
# day_8_2017: 2130.46
# mean_20_dow1_2017: 2085.80
# day_14_2017: 2073.55
# promo_2: 2063.60
# day_4_2017: 2060.79
# day_5_2017: 1997.43
# day_11_2017: 1966.00
# mean_20_dow4_2017: 1939.13
# mean_4_dow2_2017: 1925.20
# mean_4_dow3_2017: 1904.21
# day_12_2017: 1864.96
# day_13_2017: 1744.48
# mean_4_dow1_2017: 1712.83
# mean_8_2017: 1444.34
# mean_12_2017: 1201.46
# promo_14: 1154.68
# promo_8: 1007.03
# promo_13: 898.97
# promo_11: 873.19
# promo_9: 788.03
# promo_10: 741.46
# promo_12: 697.25
# promo_15: 338.03
# ==================================================
# Step 7
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.595411	valid_1's rmse: 0.630695
# [200]	training's rmse: 0.590992	valid_1's rmse: 0.625604
# [300]	training's rmse: 0.587792	valid_1's rmse: 0.622057
# [400]	training's rmse: 0.585151	valid_1's rmse: 0.619177
# [500]	training's rmse: 0.582747	valid_1's rmse: 0.616606
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.582747	valid_1's rmse: 0.616606
# mean_9_2017: 1011599.41
# mean_30_2017: 620182.43
# mean_10_2017: 500249.78
# mean_14_2017: 460509.53
# mean_8_2017: 174246.45
# mean_4_dow6_2017: 156345.16
# promo_6: 120408.55
# mean_20_dow6_2017: 79663.87
# mean_2_2017: 45377.40
# mean_3_2017: 39846.68
# mean_60_2017: 35753.59
# promo_14_2017: 25328.10
# mean_11_2017: 13996.74
# mean_20_dow5_2017: 11228.43
# mean_140_2017: 10486.74
# mean_4_dow5_2017: 8874.72
# day_1_2017: 7987.68
# promo_7: 7033.25
# promo_60_2017: 6544.20
# promo_3: 6148.41
# promo_13: 5726.27
# mean_6_2017: 5519.83
# mean_20_dow0_2017: 5239.74
# promo_0: 5020.87
# mean_5_2017: 4726.57
# day_6_2017: 4474.34
# promo_140_2017: 4221.41
# mean_4_2017: 4207.89
# mean_20_dow1_2017: 3440.51
# promo_5: 3223.17
# day_8_2017: 3192.69
# mean_4_dow0_2017: 3028.35
# day_10_2017: 2700.04
# day_9_2017: 2513.32
# promo_1: 2456.19
# mean_20_dow3_2017: 2401.53
# day_2_2017: 2388.12
# mean_13_2017: 2317.53
# day_3_2017: 2291.99
# mean_4_dow4_2017: 2247.45
# mean_7_2017: 2202.94
# mean_20_dow4_2017: 2166.04
# mean_4_dow3_2017: 2163.75
# day_4_2017: 2151.63
# mean_20_dow2_2017: 2150.42
# mean_4_dow1_2017: 2093.65
# day_7_2017: 2064.30
# day_5_2017: 2043.27
# promo_14: 2003.32
# day_14_2017: 1995.09
# promo_4: 1954.02
# day_11_2017: 1909.84
# day_13_2017: 1887.66
# mean_4_dow2_2017: 1856.41
# day_12_2017: 1633.61
# promo_2: 1535.13
# promo_9: 1492.96
# promo_8: 1126.93
# promo_15: 1053.48
# mean_12_2017: 1040.08
# promo_12: 520.07
# promo_11: 457.62
# promo_10: 455.48
# ==================================================
# Step 8
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.581709	valid_1's rmse: 0.608349
# [200]	training's rmse: 0.57702	valid_1's rmse: 0.603093
# [300]	training's rmse: 0.573559	valid_1's rmse: 0.599149
# [400]	training's rmse: 0.570904	valid_1's rmse: 0.596225
# [500]	training's rmse: 0.568576	valid_1's rmse: 0.593706
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.568576	valid_1's rmse: 0.593706
# mean_14_2017: 1211725.29
# mean_30_2017: 849746.28
# mean_9_2017: 392173.83
# mean_7_2017: 337921.28
# promo_7: 153780.56
# mean_8_2017: 148628.96
# mean_20_dow0_2017: 127039.71
# mean_4_dow0_2017: 80138.27
# mean_60_2017: 37264.89
# promo_0: 27176.79
# mean_2_2017: 22830.30
# promo_14_2017: 19875.58
# mean_140_2017: 18404.85
# promo_14: 14986.28
# promo_60_2017: 10099.70
# mean_5_2017: 7203.85
# day_1_2017: 7137.83
# mean_4_dow5_2017: 7098.40
# mean_20_dow2_2017: 6640.42
# promo_140_2017: 6140.77
# mean_6_2017: 5935.80
# day_7_2017: 5812.21
# mean_3_2017: 5576.56
# promo_6: 4360.08
# mean_12_2017: 4172.33
# promo_3: 4148.96
# promo_8: 3788.18
# mean_4_dow2_2017: 3599.64
# day_5_2017: 3541.23
# day_6_2017: 3501.23
# mean_20_dow4_2017: 3422.56
# mean_20_dow1_2017: 3295.32
# mean_20_dow5_2017: 3271.69
# mean_20_dow6_2017: 3216.48
# promo_9: 3150.85
# day_14_2017: 3071.29
# mean_10_2017: 2962.33
# promo_2: 2866.60
# mean_4_dow6_2017: 2785.15
# promo_5: 2718.31
# mean_4_2017: 2538.04
# mean_20_dow3_2017: 2417.43
# day_4_2017: 2362.56
# day_10_2017: 2303.18
# day_3_2017: 2283.41
# day_2_2017: 2232.11
# mean_4_dow1_2017: 2196.44
# promo_15: 2029.46
# day_11_2017: 1969.47
# day_8_2017: 1858.21
# day_13_2017: 1821.41
# mean_4_dow4_2017: 1794.67
# mean_4_dow3_2017: 1778.19
# day_9_2017: 1770.12
# day_12_2017: 1513.38
# mean_13_2017: 1490.11
# promo_4: 1327.29
# promo_1: 1313.87
# promo_13: 945.83
# mean_11_2017: 863.68
# promo_11: 499.03
# promo_12: 390.14
# promo_10: 331.41
# ==================================================
# Step 9
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.59034	valid_1's rmse: 0.605631
# [200]	training's rmse: 0.585791	valid_1's rmse: 0.601318
# [300]	training's rmse: 0.582783	valid_1's rmse: 0.598319
# [400]	training's rmse: 0.580125	valid_1's rmse: 0.595666
# [500]	training's rmse: 0.577751	valid_1's rmse: 0.593263
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.577751	valid_1's rmse: 0.593263
# mean_30_2017: 1126395.39
# mean_13_2017: 401193.44
# mean_14_2017: 397726.21
# mean_8_2017: 228966.63
# mean_60_2017: 177844.44
# promo_8: 114608.19
# mean_20_dow1_2017: 96409.24
# mean_7_2017: 84667.77
# mean_12_2017: 70122.49
# mean_9_2017: 66189.44
# mean_140_2017: 32052.44
# mean_6_2017: 30426.72
# mean_4_dow1_2017: 23507.56
# promo_14_2017: 22262.24
# promo_10: 12971.57
# mean_20_dow2_2017: 11856.94
# mean_2_2017: 10108.50
# promo_7: 8769.62
# mean_4_dow2_2017: 8590.66
# day_1_2017: 7929.53
# promo_60_2017: 7619.46
# day_6_2017: 7058.82
# promo_140_2017: 5515.81
# mean_5_2017: 5278.48
# mean_20_dow0_2017: 4616.10
# promo_12: 4423.57
# mean_20_dow4_2017: 3908.86
# day_5_2017: 3640.42
# mean_3_2017: 3531.99
# promo_0: 3294.16
# mean_4_dow6_2017: 2911.41
# mean_4_dow0_2017: 2861.89
# mean_20_dow6_2017: 2725.19
# mean_4_2017: 2676.14
# promo_14: 2672.96
# day_13_2017: 2556.59
# day_2_2017: 2455.29
# mean_20_dow3_2017: 2423.42
# day_3_2017: 2420.37
# promo_1: 2365.82
# day_10_2017: 2344.07
# day_7_2017: 2286.25
# mean_20_dow5_2017: 2284.83
# day_12_2017: 2273.41
# promo_9: 2189.69
# day_14_2017: 2156.95
# mean_4_dow5_2017: 2102.96
# day_4_2017: 2031.61
# mean_4_dow4_2017: 2008.67
# mean_4_dow3_2017: 1988.69
# day_8_2017: 1977.97
# mean_10_2017: 1902.75
# day_11_2017: 1835.37
# promo_4: 1789.10
# promo_3: 1778.39
# day_9_2017: 1673.55
# promo_13: 1619.06
# promo_2: 1250.43
# promo_11: 1216.87
# promo_6: 1115.37
# promo_5: 1098.99
# promo_15: 981.31
# mean_11_2017: 593.10
# ==================================================
# Step 10
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.594044	valid_1's rmse: 0.601385
# [200]	training's rmse: 0.588982	valid_1's rmse: 0.596533
# [300]	training's rmse: 0.585374	valid_1's rmse: 0.593283
# [400]	training's rmse: 0.582628	valid_1's rmse: 0.590731
# [500]	training's rmse: 0.580222	valid_1's rmse: 0.588416
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.580222	valid_1's rmse: 0.588416
# mean_30_2017: 1178570.64
# mean_14_2017: 769850.64
# mean_7_2017: 348733.31
# mean_4_dow2_2017: 321078.61
# mean_20_dow2_2017: 274242.36
# promo_9: 137556.33
# mean_12_2017: 121720.47
# mean_6_2017: 65369.61
# mean_60_2017: 42186.28
# mean_13_2017: 25371.38
# promo_14_2017: 23709.19
# day_5_2017: 11834.21
# promo_60_2017: 11704.14
# promo_2: 11347.31
# promo_140_2017: 10198.20
# promo_10: 8615.36
# promo_8: 8009.55
# promo_7: 7798.20
# mean_140_2017: 7703.62
# mean_5_2017: 6551.75
# day_1_2017: 6180.78
# mean_8_2017: 6062.87
# mean_20_dow4_2017: 5463.45
# mean_20_dow1_2017: 5350.75
# mean_2_2017: 4973.94
# promo_14: 4747.22
# mean_20_dow5_2017: 4039.85
# mean_3_2017: 4018.76
# mean_20_dow0_2017: 3932.93
# day_12_2017: 3637.16
# mean_4_2017: 3589.20
# mean_4_dow0_2017: 3481.26
# mean_20_dow6_2017: 3464.13
# promo_12: 3415.85
# day_4_2017: 3177.67
# promo_0: 3149.78
# day_6_2017: 3091.47
# mean_20_dow3_2017: 2956.99
# day_14_2017: 2845.22
# mean_4_dow3_2017: 2835.46
# day_10_2017: 2810.96
# mean_4_dow1_2017: 2495.45
# promo_11: 2430.06
# day_13_2017: 2401.03
# mean_4_dow4_2017: 2244.38
# mean_4_dow5_2017: 2210.44
# day_3_2017: 2197.57
# promo_13: 2165.59
# mean_9_2017: 2089.97
# mean_4_dow6_2017: 1960.71
# day_7_2017: 1880.34
# day_2_2017: 1829.23
# day_11_2017: 1758.38
# promo_15: 1644.88
# day_9_2017: 1561.01
# promo_1: 1430.21
# day_8_2017: 1389.63
# mean_11_2017: 1231.93
# promo_6: 938.25
# promo_4: 900.22
# promo_3: 898.72
# mean_10_2017: 853.18
# promo_5: 337.37
# ==================================================
# Step 11
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.607237	valid_1's rmse: 0.608805
# [200]	training's rmse: 0.602262	valid_1's rmse: 0.60417
# [300]	training's rmse: 0.598614	valid_1's rmse: 0.600729
# [400]	training's rmse: 0.595723	valid_1's rmse: 0.597961
# [500]	training's rmse: 0.593064	valid_1's rmse: 0.595538
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.593064	valid_1's rmse: 0.595538
# mean_30_2017: 1334902.29
# mean_12_2017: 671737.93
# mean_4_dow3_2017: 288205.64
# mean_14_2017: 224585.27
# mean_6_2017: 201164.09
# mean_60_2017: 188656.14
# mean_13_2017: 178377.91
# mean_5_2017: 170934.71
# mean_20_dow3_2017: 145688.82
# promo_10: 110084.40
# mean_7_2017: 82465.00
# mean_4_2017: 34898.76
# mean_140_2017: 33993.19
# promo_14_2017: 20365.82
# mean_4_dow4_2017: 14122.26
# promo_12: 10408.05
# day_3_2017: 9105.41
# promo_60_2017: 8239.82
# mean_20_dow2_2017: 7478.03
# promo_140_2017: 7371.20
# promo_14: 7309.73
# promo_7: 6936.01
# mean_11_2017: 6498.98
# promo_11: 6256.63
# promo_8: 5797.40
# mean_20_dow5_2017: 5043.31
# mean_3_2017: 4757.84
# promo_9: 4640.85
# day_4_2017: 4380.07
# mean_4_dow2_2017: 4172.11
# mean_20_dow6_2017: 3964.68
# mean_20_dow0_2017: 3496.82
# day_1_2017: 3381.30
# mean_8_2017: 3340.03
# promo_0: 3197.19
# day_11_2017: 3090.09
# day_5_2017: 3058.50
# promo_13: 3026.29
# mean_20_dow1_2017: 2976.35
# mean_2_2017: 2903.12
# mean_20_dow4_2017: 2560.10
# day_10_2017: 2436.74
# promo_3: 2282.20
# mean_4_dow0_2017: 2274.61
# day_2_2017: 2131.15
# mean_4_dow1_2017: 2128.30
# day_14_2017: 2075.40
# day_12_2017: 2057.76
# mean_4_dow6_2017: 2032.79
# mean_4_dow5_2017: 2026.50
# mean_10_2017: 1957.86
# mean_9_2017: 1810.08
# day_9_2017: 1734.54
# day_6_2017: 1650.82
# day_8_2017: 1647.80
# day_7_2017: 1633.06
# promo_15: 1564.53
# day_13_2017: 1421.65
# promo_6: 1397.88
# promo_2: 1222.64
# promo_1: 1064.91
# promo_4: 645.05
# promo_5: 463.02
# ==================================================
# Step 12
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.61475	valid_1's rmse: 0.618112
# [200]	training's rmse: 0.609468	valid_1's rmse: 0.613273
# [300]	training's rmse: 0.606054	valid_1's rmse: 0.609896
# [400]	training's rmse: 0.603164	valid_1's rmse: 0.607105
# [500]	training's rmse: 0.600479	valid_1's rmse: 0.604539
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.600479	valid_1's rmse: 0.604539
# mean_4_dow4_2017: 1339140.11
# mean_11_2017: 1259595.34
# mean_30_2017: 320046.66
# mean_4_2017: 250823.65
# mean_20_dow4_2017: 240373.00
# mean_5_2017: 134101.17
# mean_10_2017: 133643.24
# promo_11: 109207.47
# mean_60_2017: 92724.98
# mean_14_2017: 39535.90
# mean_140_2017: 37173.54
# promo_14_2017: 23538.09
# promo_12: 15731.55
# day_3_2017: 15649.30
# promo_14: 10120.54
# mean_4_dow3_2017: 8813.57
# promo_140_2017: 7191.95
# promo_60_2017: 6119.93
# promo_10: 5786.81
# mean_13_2017: 5708.17
# mean_20_dow3_2017: 5656.38
# promo_4: 5649.98
# mean_3_2017: 5469.47
# promo_7: 5372.80
# mean_12_2017: 5333.89
# mean_6_2017: 5289.17
# promo_13: 5227.78
# day_10_2017: 5050.92
# promo_9: 4945.56
# mean_20_dow1_2017: 4722.52
# mean_20_dow2_2017: 4033.94
# mean_20_dow0_2017: 3996.08
# mean_20_dow6_2017: 3529.74
# promo_8: 3475.52
# mean_20_dow5_2017: 3216.27
# promo_0: 2896.59
# mean_2_2017: 2816.94
# day_4_2017: 2761.59
# day_1_2017: 2736.29
# mean_7_2017: 2652.80
# mean_4_dow0_2017: 2322.41
# promo_15: 2251.07
# mean_4_dow5_2017: 2150.84
# day_5_2017: 2133.86
# day_14_2017: 2072.72
# day_11_2017: 2063.43
# day_2_2017: 2005.78
# mean_4_dow6_2017: 1949.29
# mean_4_dow2_2017: 1880.58
# mean_8_2017: 1849.88
# day_12_2017: 1846.84
# day_7_2017: 1758.46
# day_13_2017: 1755.25
# mean_4_dow1_2017: 1749.95
# day_9_2017: 1731.62
# mean_9_2017: 1730.79
# day_6_2017: 1668.73
# day_8_2017: 1436.79
# promo_6: 1274.90
# promo_1: 1067.72
# promo_2: 907.06
# promo_3: 436.12
# promo_5: 360.93
# ==================================================
# Step 13
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.610932	valid_1's rmse: 0.609442
# [200]	training's rmse: 0.606387	valid_1's rmse: 0.605321
# [300]	training's rmse: 0.603108	valid_1's rmse: 0.602288
# [400]	training's rmse: 0.60027	valid_1's rmse: 0.59966
# [500]	training's rmse: 0.59778	valid_1's rmse: 0.597356
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.59778	valid_1's rmse: 0.597356
# mean_30_2017: 1343090.47
# mean_10_2017: 794678.12
# mean_14_2017: 384605.18
# mean_60_2017: 187188.69
# promo_12: 120949.51
# mean_20_dow5_2017: 93130.85
# mean_3_2017: 84825.01
# mean_4_2017: 77910.73
# mean_4_dow5_2017: 62300.28
# mean_9_2017: 57876.33
# mean_140_2017: 31130.55
# mean_11_2017: 29009.36
# mean_12_2017: 23975.41
# mean_5_2017: 21335.75
# promo_14_2017: 20458.69
# mean_2_2017: 8301.63
# promo_14: 8043.09
# promo_60_2017: 7323.10
# mean_20_dow6_2017: 6910.05
# mean_8_2017: 6664.81
# promo_13: 6611.16
# promo_140_2017: 5877.93
# promo_10: 5683.23
# mean_20_dow0_2017: 5036.87
# mean_13_2017: 4170.97
# promo_7: 3975.25
# day_2_2017: 3805.23
# day_1_2017: 3551.86
# promo_11: 3491.01
# mean_20_dow3_2017: 3355.75
# mean_20_dow2_2017: 3221.86
# mean_4_dow0_2017: 3044.32
# day_14_2017: 3002.00
# promo_0: 2968.03
# mean_20_dow1_2017: 2904.62
# day_3_2017: 2843.05
# mean_4_dow6_2017: 2805.95
# promo_8: 2769.28
# promo_15: 2583.98
# mean_4_dow4_2017: 2580.38
# day_10_2017: 2522.23
# day_6_2017: 2510.84
# mean_6_2017: 2466.50
# day_9_2017: 2348.37
# mean_4_dow2_2017: 2328.34
# day_13_2017: 2324.85
# mean_20_dow4_2017: 2288.76
# mean_4_dow1_2017: 2196.85
# day_7_2017: 2148.04
# day_5_2017: 2054.91
# mean_4_dow3_2017: 2009.75
# day_12_2017: 1984.74
# day_4_2017: 1935.31
# day_11_2017: 1815.88
# promo_5: 1802.00
# mean_7_2017: 1779.21
# day_8_2017: 1764.53
# promo_9: 1759.70
# promo_6: 1458.14
# promo_4: 1052.24
# promo_1: 659.82
# promo_2: 623.98
# promo_3: 584.31
# ==================================================
# Step 14
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.61188	valid_1's rmse: 0.598948
# [200]	training's rmse: 0.607172	valid_1's rmse: 0.594843
# [300]	training's rmse: 0.604049	valid_1's rmse: 0.592058
# [400]	training's rmse: 0.601112	valid_1's rmse: 0.589533
# [500]	training's rmse: 0.598685	valid_1's rmse: 0.587281
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.598685	valid_1's rmse: 0.587281
# mean_30_2017: 1505782.33
# mean_14_2017: 550520.40
# mean_9_2017: 262099.91
# mean_10_2017: 164492.32
# mean_20_dow6_2017: 147835.45
# promo_13: 146962.93
# mean_4_dow6_2017: 106118.42
# mean_60_2017: 99603.45
# mean_3_2017: 64468.75
# mean_8_2017: 57000.98
# mean_4_2017: 23621.95
# promo_14_2017: 19209.01
# mean_2_2017: 15571.75
# mean_20_dow5_2017: 13281.03
# promo_12: 12009.96
# day_1_2017: 10881.57
# promo_14: 10653.37
# promo_60_2017: 10024.75
# mean_140_2017: 9680.38
# mean_5_2017: 9008.47
# mean_20_dow1_2017: 7388.30
# promo_140_2017: 6755.27
# mean_20_dow0_2017: 6338.15
# day_14_2017: 5825.79
# promo_6: 5518.49
# mean_6_2017: 5454.65
# mean_13_2017: 5394.03
# mean_4_dow5_2017: 4570.35
# day_13_2017: 3884.14
# promo_10: 3511.46
# promo_7: 3501.57
# promo_0: 3296.61
# mean_4_dow0_2017: 3179.09
# promo_15: 3155.40
# day_3_2017: 3138.85
# mean_20_dow3_2017: 2946.17
# mean_7_2017: 2776.15
# day_5_2017: 2609.84
# mean_4_dow1_2017: 2600.16
# day_8_2017: 2586.18
# mean_20_dow2_2017: 2557.90
# day_7_2017: 2537.29
# mean_20_dow4_2017: 2483.61
# mean_4_dow4_2017: 2423.36
# mean_4_dow3_2017: 2397.86
# mean_4_dow2_2017: 2233.55
# day_10_2017: 2208.13
# promo_8: 2199.01
# day_2_2017: 2194.86
# day_11_2017: 2040.88
# day_4_2017: 2020.13
# day_12_2017: 1956.48
# day_9_2017: 1871.67
# day_6_2017: 1843.44
# promo_9: 1592.47
# promo_11: 1555.62
# promo_1: 1410.69
# mean_12_2017: 1366.57
# mean_11_2017: 1277.89
# promo_3: 1064.15
# promo_2: 844.42
# promo_4: 759.95
# promo_5: 494.61
# ==================================================
# Step 15
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.597711	valid_1's rmse: 0.586987
# [200]	training's rmse: 0.592568	valid_1's rmse: 0.582596
# [300]	training's rmse: 0.589173	valid_1's rmse: 0.579764
# [400]	training's rmse: 0.586282	valid_1's rmse: 0.577191
# [500]	training's rmse: 0.583731	valid_1's rmse: 0.574863
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.583731	valid_1's rmse: 0.574863
# mean_30_2017: 1593380.31
# mean_14_2017: 750057.29
# promo_14: 181921.01
# mean_20_dow0_2017: 156935.36
# mean_7_2017: 124546.33
# mean_60_2017: 113115.61
# mean_9_2017: 102897.22
# mean_8_2017: 93168.30
# mean_4_dow0_2017: 69493.05
# mean_5_2017: 31413.52
# mean_140_2017: 29561.44
# mean_6_2017: 22267.70
# promo_14_2017: 21433.09
# promo_0: 19053.50
# promo_7: 14785.05
# mean_2_2017: 13994.89
# mean_20_dow2_2017: 13366.35
# day_14_2017: 12695.33
# promo_60_2017: 11905.56
# promo_140_2017: 10685.29
# mean_3_2017: 8714.39
# promo_12: 7172.96
# promo_13: 5070.73
# day_1_2017: 5035.04
# mean_20_dow1_2017: 4894.75
# day_7_2017: 4691.38
# mean_4_2017: 4565.32
# promo_15: 4410.25
# mean_20_dow6_2017: 4078.42
# promo_9: 3916.02
# mean_4_dow2_2017: 3514.08
# mean_20_dow4_2017: 3432.46
# mean_20_dow5_2017: 3195.36
# promo_10: 2905.50
# day_13_2017: 2758.38
# day_5_2017: 2746.53
# mean_4_dow5_2017: 2677.82
# day_2_2017: 2664.67
# day_3_2017: 2653.41
# mean_20_dow3_2017: 2557.06
# day_10_2017: 2344.49
# promo_8: 2319.00
# mean_11_2017: 2243.73
# mean_4_dow1_2017: 2214.85
# day_11_2017: 2107.47
# mean_4_dow6_2017: 2107.22
# mean_4_dow4_2017: 2088.91
# mean_4_dow3_2017: 2048.50
# promo_11: 1985.33
# promo_2: 1970.34
# day_12_2017: 1965.02
# mean_13_2017: 1956.40
# day_6_2017: 1829.56
# day_4_2017: 1818.09
# day_8_2017: 1757.57
# day_9_2017: 1685.36
# promo_6: 1510.29
# promo_4: 1509.04
# mean_10_2017: 1507.81
# promo_1: 1189.42
# mean_12_2017: 987.10
# promo_5: 491.45
# promo_3: 464.54
# ==================================================
# Step 16
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.605599	valid_1's rmse: 0.604925
# [200]	training's rmse: 0.601116	valid_1's rmse: 0.60051
# [300]	training's rmse: 0.597897	valid_1's rmse: 0.597291
# [400]	training's rmse: 0.59523	valid_1's rmse: 0.594743
# [500]	training's rmse: 0.59259	valid_1's rmse: 0.592218
# Did not meet early stopping. Best iteration is:
# [500]	training's rmse: 0.59259	valid_1's rmse: 0.592218
# mean_30_2017: 1396877.86
# mean_14_2017: 695875.92
# mean_60_2017: 147069.77
# promo_15: 124656.48
# mean_7_2017: 122048.35
# mean_20_dow1_2017: 99177.65
# mean_13_2017: 46101.34
# mean_140_2017: 42735.11
# mean_8_2017: 42132.51
# mean_5_2017: 33397.42
# mean_20_dow2_2017: 25782.07
# mean_6_2017: 25268.82
# promo_14_2017: 17653.90
# mean_4_dow1_2017: 13719.00
# promo_14: 12477.34
# promo_60_2017: 10548.64
# mean_4_dow2_2017: 9466.53
# promo_140_2017: 8351.19
# day_13_2017: 7431.36
# day_1_2017: 7017.98
# mean_2_2017: 5977.92
# mean_3_2017: 5121.45
# mean_20_dow4_2017: 4288.36
# mean_20_dow0_2017: 4270.18
# promo_8: 4257.87
# day_14_2017: 3946.18
# promo_13: 3826.27
# day_6_2017: 3704.38
# promo_12: 3607.99
# day_12_2017: 3497.89
# mean_12_2017: 3224.92
# day_10_2017: 3159.72
# promo_10: 3132.69
# promo_0: 2954.20
# day_5_2017: 2862.61
# mean_20_dow3_2017: 2822.97
# mean_4_dow3_2017: 2789.81
# day_3_2017: 2720.58
# mean_20_dow6_2017: 2682.35
# mean_20_dow5_2017: 2621.07
# mean_4_dow0_2017: 2603.38
# day_4_2017: 2556.08
# mean_4_dow6_2017: 2466.38
# mean_4_dow5_2017: 2195.61
# mean_4_dow4_2017: 2124.06
# day_11_2017: 2107.03
# day_2_2017: 2050.21
# day_7_2017: 2030.14
# day_8_2017: 1991.71
# promo_7: 1987.45
# day_9_2017: 1820.06
# mean_9_2017: 1760.16
# mean_4_2017: 1716.13
# mean_10_2017: 1348.54
# promo_2: 1154.56
# mean_11_2017: 1146.25
# promo_9: 1064.37
# promo_1: 1023.61
# promo_11: 795.31
# promo_4: 767.32
# promo_6: 444.65
# promo_3: 441.79
# promo_5: 226.37

# %%
print("Validation mse:", mean_squared_error(
    y_val, np.array(val_pred).transpose())**0.5)
# Out:
# Validation mse: 0.583640655433

# %%
print("Making submission...")
y_test = np.array(test_pred).transpose()
df_preds = pd.DataFrame(y_test, index=df_2017.index, columns=pd.date_range("2017-08-16", periods=16)
                       ).stack().to_frame("unit_sales")
df_preds.index.set_names(["store_nbr", "item_nbr", "date"], inplace=True)
# Out:
# Making submission...

# %%
submission = df_test[["id"]].join(df_preds, how="left").fillna(0)
submission["unit_sales"] = np.clip(np.expm1(submission["unit_sales"]), 0, 10000)
submission.shape
# Out:
# (3370464, 2)

# %%
submission.to_csv('try2.csv', float_format='%.4f', index=None)
